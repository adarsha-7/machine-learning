# %% [markdown]
# # Random Forest

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1)

X = mnist.data
y = mnist.target

X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
import time

rf = RandomForestClassifier(random_state=42)
rf_start = time.time()
rf.fit(X_train, y_train)
rf_end = time.time()

rf_pred = rf.predict(X_test)

print("Training Time: ", rf_end - rf_start)
print("Accuracy: ", accuracy_score(rf_pred, y_test))
# Out:
# Training Time:  90.3875994682312
# Accuracy:  0.9705

# %%
pca = PCA(n_components=0.95)
X_train_red = pca.fit_transform(X_train)
X_test_red = pca.transform(X_test)
pca.n_components_
# Out:
# np.int64(154)

# %%
pca_rf = RandomForestClassifier(random_state=42)
pca_rf_start = time.time()
pca_rf.fit(X_train_red, y_train)
pca_rf_end = time.time()

pca_rf_pred = pca_rf.predict(X_test_red)

print("Training Time: ", pca_rf_end - pca_rf_start)
print("Accuracy: ", accuracy_score(pca_rf_pred, y_test))
# Out:
# Training Time:  285.64624404907227
# Accuracy:  0.9488

# %% [markdown]
# # SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier(random_state=42)
sgd_start = time.time()
sgd.fit(X_train, y_train)
sgd_end = time.time()

sgd_pred = sgd.predict(X_test)

print("Training Time: ", sgd_end - sgd_start)
print("Accuracy: ", accuracy_score(sgd_pred, y_test))
# Out:
# Training Time:  242.9207456111908
# Accuracy:  0.874

# %%
pca_sgd = SGDClassifier(random_state=42)
pca_sgd_start = time.time()
pca_sgd.fit(X_train_red, y_train)
pca_sgd_end = time.time()

pca_sgd_pred = pca_sgd.predict(X_test_red)

print("Training Time: ", pca_sgd_end - pca_sgd_start)
print("Accuracy: ", accuracy_score(pca_sgd_pred, y_test))
# Out:
# Training Time:  50.00172448158264
# Accuracy:  0.8959
