# %% [markdown]
# Train an SVM classifier on the wine dataset, which you can load using
# sklearn.datasets.load_wine(). This dataset contains the chemical analyses
# of 178 wine samples produced by 3 different cultivators: the goal is to train
# a classification model capable of predicting the cultivator based on the wine’s
# chemical analysis. Since SVM classifiers are binary classifiers, you will need to
# use one-versus-all to classify all three classes. What accuracy can you reach?

# %%
from sklearn.datasets import load_wine

wine = load_wine(as_frame=True)

# %%
wine.data
# Out:
#      alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0      14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1      13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2      13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3      14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4      13.24        2.59  2.87  ...  1.04                          2.93    735.0
# ..       ...         ...   ...  ...   ...                           ...      ...
# 173    13.71        5.65  2.45  ...  0.64                          1.74    740.0
# 174    13.40        3.91  2.48  ...  0.70                          1.56    750.0
# 175    13.27        4.28  2.26  ...  0.59                          1.56    835.0
# 176    13.17        2.59  2.37  ...  0.60                          1.62    840.0
# 177    14.13        4.10  2.74  ...  0.61                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, random_state=42)

# %% [markdown]
# LinearSVC

# %%
from sklearn.svm import LinearSVC

lin_clf = LinearSVC(dual=True, max_iter = 1000000, random_state=42)
lin_clf.fit(X_train, y_train)
# Out:
# d:\programming\machine_learning\.venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC(dual=True, max_iter=1000000, random_state=42)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(lin_clf, X_train, y_train, cv=5)
# Out:
# d:\programming\machine_learning\.venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\programming\machine_learning\.venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\programming\machine_learning\.venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\programming\machine_learning\.venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\programming\machine_learning\.venv\Lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# array([0.88888889, 0.88888889, 0.92592593, 0.92307692, 0.92307692])

# %% [markdown]
# We have problems of not converging because we have not scaled. We will scale and do now.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

lin_clf = make_pipeline(
    StandardScaler(),
    LinearSVC(dual=True, random_state=42)
)
lin_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearsvc', LinearSVC(dual=True, random_state=42))])

# %%
cross_val_score(lin_clf, X_train, y_train, cv=5).mean()
# Out:
# np.float64(0.9774928774928775)

# %% [markdown]
# Using kernelized SVM.

# %%
from sklearn.svm import SVC

svm_clf = make_pipeline(
    StandardScaler(), 
    SVC(random_state=42)
    )
cross_val_score(svm_clf, X_train, y_train).mean()
# Out:
# np.float64(0.9698005698005698)

# %% [markdown]
# Hyperparameter tuning
